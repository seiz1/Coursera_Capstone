# %% [markdown]
# # Capstone Project Notebook
#
# This notebook will contain textual description and code required to complete the capstone project of **IBM Data Science** Coursera specialization.

# %%
#!conda install -n Coursera_Capstone numpy -y
#!conda install -n Coursera_Capstone pandas -y

# %%
import pandas as pd
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
